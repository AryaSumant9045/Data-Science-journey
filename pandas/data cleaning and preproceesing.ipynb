# %%
import pandas as pd
df = pd.read_csv("data_cleaning_sample.csv")
df
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "F:\Users\MY PC\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "F:\Users\MY PC\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "F:\Users\MY PC\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
# ...

# %%
df.isnull()
# Out:
#     Name    Age   City  Gender  Email  Join Date
# 0  False  False  False   False  False      False
# 1  False  False  False   False  False      False
# 2  False   True  False   False  False      False
# 3  False  False  False   False  False      False
# 4   True  False  False   False  False       True

# %%
df.isnull().sum()  # per column mai kitni null value hai
# Out:
# Name         1
# Age          1
# City         0
# Gender       0
# Email        0
# Join Date    1
# dtype: int64

# %%
df.dropna() #drop row
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  2021-05-01
# 1    Bob  30.0  Los Angeles      M    bob@example.com  2020-06-15
# 3  David  22.0       Mumbai      M  david@example.com  2019-11-12

# %%
df.dropna(axis = 1)  # column drop
# Out:
#           City Gender              Email
# 0     New York      F  alice@example.com
# 1  Los Angeles      M    bob@example.com
# 2        Delhi      M    charlie@example
# 3       Mumbai      M  david@example.com
# 4        Delhi      F     eve@domain.com

# %%
df.fillna(0)
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 1      Bob  30.0  Los Angeles      M    bob@example.com  2020-06-15
# 2  Charlie   0.0        Delhi      M    charlie@example  2021-07-20
# 3    David  22.0       Mumbai      M  david@example.com  2019-11-12
# 4        0  28.0        Delhi      F     eve@domain.com           0

# %%
df["Age"].fillna(df["Age"].mean())
# Out:
# 0    25.00
# 1    30.00
# 2    26.25
# 3    22.00
# 4    28.00
# Name: Age, dtype: float64

# %%
df.fillna(method = "bfill")
# Out:
# C:\Users\MY PC\AppData\Local\Temp\ipykernel_2760\3988041702.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "bfill")
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 1      Bob  30.0  Los Angeles      M    bob@example.com  2020-06-15
# 2  Charlie  22.0        Delhi      M    charlie@example  2021-07-20
# 3    David  22.0       Mumbai      M  david@example.com  2019-11-12
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN

# %%
df.ffill()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 1      Bob  30.0  Los Angeles      M    bob@example.com  2020-06-15
# 2  Charlie  30.0        Delhi      M    charlie@example  2021-07-20
# 3    David  22.0       Mumbai      M  david@example.com  2019-11-12
# 4    David  28.0        Delhi      F     eve@domain.com  2019-11-12

# %%
import pandas as pd
df = pd.read_csv("data_cleaning_with_duplicates.csv")
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 1      Bob  30.0  Los Angeles      M    bob@example.com  2020-06-15
# 2  Charlie   NaN        Delhi      M    charlie@example  2021-07-20
# 3    David  22.0       Mumbai      M  david@example.com  2019-11-12
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 5      Bob  30.0  Los Angeles      M    bob@example.com  2020-06-15

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 1      Bob  30.0  Los Angeles      M    bob@example.com  2020-06-15
# 2  Charlie   NaN        Delhi      M    charlie@example  2021-07-20
# 3    David  22.0       Mumbai      M  david@example.com  2019-11-12
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN

# %%
df.duplicated(subset=["Name","Age"])   #Ye basically combination ko dhekta hai
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
df["Name"].str.lower()
# Out:
# 0      alice
# 1        bob
# 2    charlie
# 3      david
# 4        NaN
# 5        bob
# Name: Name, dtype: object

# %%
df["City"].str.contains("delhi", case=False)  # yha case false krne se casesensitivity kam nhi kregi
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# Name: City, dtype: bool

# %%
type(df["City"].str.contains("delhi", case=False))
# Out:
# pandas.core.series.Series

# %%
df["Email"].str.split("@")
# Out:
# 0    [alice, example.com]
# 1      [bob, example.com]
# 2      [charlie, example]
# 3    [david, example.com]
# 4       [eve, domain.com]
# 5      [bob, example.com]
# Name: Email, dtype: object

# %%
type(df["Email"].str.split("@")[0])
# Out:
# list

# %%
df2 = df.dropna().copy()
df2["Age"] = df2["Age"].astype(int)
df2
# Out:
#     Name  Age         City Gender              Email   Join Date
# 0  Alice   25     New York      F  alice@example.com  2021-05-01
# 1    Bob   30  Los Angeles      M    bob@example.com  2020-06-15
# 3  David   22       Mumbai      M  david@example.com  2019-11-12
# 5    Bob   30  Los Angeles      M    bob@example.com  2020-06-15

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       4 non-null      object
#  1   Age        4 non-null      int64
#  2   City       4 non-null      object
#  3   Gender     4 non-null      object
#  4   Email      4 non-null      object
#  5   Join Date  4 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 224.0+ bytes

# %%
def isminor(x):
    return "Adult" if x>25 else "Minor"
df2["Age Group"] = df2["Age"].apply(isminor)

# df2["Age Group"] = df2["Age"].apply(lambda x : "Adult" if x>25 else "Minor")
df2
# Out:
#     Name  Age         City Gender              Email   Join Date Age Group
# 0  Alice   25     New York      F  alice@example.com  2021-05-01     Minor
# 1    Bob   30  Los Angeles      M    bob@example.com  2020-06-15     Adult
# 3  David   22       Mumbai      M  david@example.com  2019-11-12     Minor
# 5    Bob   30  Los Angeles      M    bob@example.com  2020-06-15     Adult

# %%
Gender_map = {"M":"Male", "F":"Female", "O":"Other"}
df2["Gender"]= df2["Gender"].map(Gender_map)
df2
# Out:
#     Name  Age         City  Gender              Email   Join Date Age Group
# 0  Alice   25     New York  Female  alice@example.com  2021-05-01     Minor
# 1    Bob   30  Los Angeles    Male    bob@example.com  2020-06-15     Adult
# 3  David   22       Mumbai    Male  david@example.com  2019-11-12     Minor
# 5    Bob   30  Los Angeles    Male    bob@example.com  2020-06-15     Adult

# %%
df["City"] = df["City"].replace({"Delhi":"New Delhi", "Mumbai":"New Mumbai"})
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 1      Bob  30.0  Los Angeles      M    bob@example.com  2020-06-15
# 2  Charlie   NaN    New Delhi      M    charlie@example  2021-07-20
# 3    David  22.0   New Mumbai      M  david@example.com  2019-11-12
# 4      NaN  28.0    New Delhi      F     eve@domain.com         NaN
# 5      Bob  30.0  Los Angeles      M    bob@example.com  2020-06-15
