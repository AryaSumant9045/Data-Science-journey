# %%
import seaborn as sns
import numpy as np

x = np.array([13, 3,3 ,1,2, 4, 65, 54, 32, 23, 23,3,21, 23,54,45,2,5,79,0,76,90,33])
y= np.sin(x)

sns.set_theme(style="darkgrid")
sns.lineplot(x=x, y=y)
# Out:
# <Axes: >

# %%
#!pip install --upgrade numpy seaborn matplotlib --force-reinstall
import numpy
import seaborn
import matplotlib

print("numpy:", numpy.__version__)
print("seaborn:", seaborn.__version__)
print("matplotlib:", matplotlib.__version__)
# Out:
# numpy: 1.26.4
# seaborn: 0.13.2
# matplotlib: 3.10.3
